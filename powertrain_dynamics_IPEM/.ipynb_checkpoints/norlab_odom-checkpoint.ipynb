# %%
# import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %run ./scripts/util_func.py

# %%
# import data to dataframe

data = pd.read_csv("/home/dominic/Documents/publications/sensors2021/offline_model_training/powertrain_dynamics_IPEM/data/data_wheel_odom.csv") 

data = data.iloc[1:]

print(data)
# Out:
#        Unnamed: 0      ros_time  wheel_meas_index  cmd_left_vel  \
# 1               1  1.603824e+18               0.0           0.0
# 2               2  1.603824e+18               0.0           0.0
# 3               3  1.603824e+18               0.0           0.0
# 4               4  1.603824e+18               0.0           0.0
# 5               5  1.603824e+18               0.0           0.0
# ...           ...           ...               ...           ...
# 17269       17269  1.603825e+18            3366.0           0.0
# 17270       17270  1.603825e+18            3366.0           0.0
# 17271       17271  1.603825e+18            3366.0           0.0
# 17272       17272  1.603825e+18            3366.0           0.0
# 17273       17273  1.603825e+18            3366.0           0.0
#
#        meas_left_vel  cmd_right_vel  meas_right_vel  warthog_odom_lin_vel  \
# 1                0.0            0.0         0.00000          0.000000e+00
# ...

# %%
# convert dataframe to numpy array

array = data.to_numpy()
array =np.delete(array,[0],axis=0)

time_arr = array[:,1]
time_arr = (time_arr - time_arr[0]) * 10**(-9)
meas_index_arr = array[:,2]

left_vel_cmd_arr = array[:,3]
left_vel_meas_arr = array[:,4]
right_vel_cmd_arr = array[:,5]
right_vel_meas_arr = array[:,6]

linear_odom_vel_arr = array[:,7]
angular_odom_vel_arr = array[:,8]

left_EKF_vel = np.genfromtxt('data/left_ekf_mod_vel.csv', delimiter=',')
right_EKF_vel = np.genfromtxt('data/right_ekf_mod_vel.csv', delimiter=',')

# %%
plt.figure(2, figsize=(20,8))
plt.subplot(211)
plt.plot(time_arr, linear_odom_vel_arr, c='tab:blue', label='tau_c_left')
plt.subplot(212)
plt.plot(time_arr, angular_odom_vel_arr, c='tab:orange', label='tau_c_right')

# %%
# Run model on all data

# init tau_c and tau_d values

tau_c = 0.2
tau_d = 0.25

left_model_vel = np.zeros((meas_index_arr.shape[0]))
right_model_vel = np.zeros((meas_index_arr.shape[0]))

for i in range(10, meas_index_arr.shape[0]-1):
    
    dt = (time_arr[i] - time_arr[i-1])
    left_model_vel[i+1] = powerTrain_vel(tau_c, tau_d, left_vel_cmd_arr, left_EKF_vel, i, dt)
    right_model_vel[i+1] = powerTrain_vel(tau_c, tau_d, right_vel_cmd_arr, right_EKF_vel, i, dt)

# %%
# compute diff_drive model

r = 0.3 # wheel radius (m)
B = 1.2 # wheel baseline (m)

enc_linear_odom_arr = np.zeros((meas_index_arr.shape[0]))
enc_angular_odom_arr = np.zeros((meas_index_arr.shape[0]))

model_linear_odom_arr = np.zeros((meas_index_arr.shape[0]))
model_angular_odom_arr = np.zeros((meas_index_arr.shape[0]))

ekf_linear_odom_arr = np.zeros((meas_index_arr.shape[0]))
ekf_angular_odom_arr = np.zeros((meas_index_arr.shape[0]))

for i in range(left_vel_cmd_arr.shape[0]):
    enc_linear_odom_arr[i], enc_angular_odom_arr[i] = diff_drive(left_vel_meas_arr, right_vel_meas_arr[i], r, B)
    model_linear_odom_arr[i], model_angular_odom_arr[i] = diff_drive(left_model_vel[i], right_model_vel[i], r, B)
    ekf_linear_odom_arr[i], ekf_angular_odom_arr[i] = diff_drive(left_EKF_vel[i], right_EKF_vel[i], r, B)

# %%
slice_start = 10000
slice_end = 13300

plt.figure(2, figsize=(20,8))
plt.subplot(211)
plt.plot(time_arr[slice_start:slice_end], linear_odom_vel_arr[slice_start:slice_end], c='tab:blue', label='warthog_odom_lin')
plt.plot(time_arr[slice_start:slice_end], cmd_linear_odom_arr[slice_start:slice_end], c='tab:orange', label='cmd_odom_lin', linestyle = 'dotted')
plt.plot(time_arr[slice_start:slice_end], enc_linear_odom_arr[slice_start:slice_end], c='tab:orange', label='encoders_odom_lin', linestyle = 'dashdot')
plt.plot(time_arr[slice_start:slice_end], model_linear_odom_arr[slice_start:slice_end], c='tab:green', label='model_odom_lin', linestyle = 'dashed')
plt.plot(time_arr[slice_start:slice_end], ekf_linear_odom_arr[slice_start:slice_end], c='tab:purple', label='ekf_odom_lin', linestyle = 'dotted')
plt.legend()
plt.subplot(212)
plt.plot(time_arr[slice_start:slice_end], angular_odom_vel_arr[slice_start:slice_end], c='tab:blue', label='warthog_odom_ang')
plt.plot(time_arr[slice_start:slice_end], norlab_angular_odom_arr[slice_start:slice_end], c='tab:orange', label='ekf_odom_ang', linestyle = 'dashed')
plt.legend()

# %%
# plot odom linear and angular velocities
slice_start = 1
slice_end = 17000

fig, ax1 = plt.subplots(figsize=(20, 20))
odom_vel = ax1.scatter(linear_odom_vel_arr[slice_start:slice_end], angular_odom_vel_arr[slice_start:slice_end], c = 'tab:blue', label = 'odom_vel')
fig.colorbar(odom_vel)

plt.show()
